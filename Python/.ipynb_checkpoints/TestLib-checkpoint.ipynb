# %% [markdown]
# ## Test Lib.
# Este escript se usará para probar las librerias de imaganes hiperespectrales. Se implementaran las pricipales libr en Python y se probará

# %%
import spectral.io.envi as envi
#import spectral
from spectral import *
import numpy as np
import matplotlib.pyplot as plt
import wx
from wx import glcanvas

# %%
#spectral.settings.WX_GL_DEPTH_SIZE = 16
#img = envi.open('/home/juand/Documents/Hyper/Experiment_2/Tommy/control_group/sample_1/tom_cgs_01_16000_us_2x_2019-11-24T121227_corr.hdr', '/home/juand/Documents/Hyper/Experiment_2/Tommy/control_group/sample_1/tom_cgs_01_16000_us_2x_2019-11-24T121227_corr.hyspex')
#Cargar datos.

#data_hdr     = '/home/juand/Hyper/Experiment_2/Test/test_d6/test_16000_us_2x_2019-11-29T111436_corr.hdr'
#data_hyspex  = '/home/juand/Hyper/Experiment_2/Test/test_d6/test_16000_us_2x_2019-11-29T111436_corr.hyspex'
data_hdr     = '/home/juand/Hyper/Experiment_2/Tommy/control_group/sample_1/tom_cgs_01_16000_us_2x_2019-11-24T121227_corr.hdr'
data_hyspex  = '/home/juand/Hyper/Experiment_2/Tommy/control_group/sample_1/tom_cgs_01_16000_us_2x_2019-11-24T121227_corr.hyspex'


img = envi.open(data_hdr,data_hyspex)
#img = envi.open(data_hdr)

print(img)
#img.info()
#view = imshow(img)
#view_nd(img)
#save_rgb('rgb.jpg', img, [29, 19, 9])
# Out:
# 	Data Source:   '/home/juand/Hyper/Experiment_2/Tommy/control_group/sample_1/tom_cgs_01_16000_us_2x_2019-11-24T121227_corr.hyspex'
# 	# Rows:           3800
# 	# Samples:        1600
# 	# Bands:           160
# 	Interleave:        BIL
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
view = imshow(img)
print(view)
# Out:
# ImageView object:
#   Display bands       :  [55, 41, 12]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 33950.0]
#     G: [0.0, 27610.0]
#     B: [0.0, 6812.0]

# %%
ImageView(img)
# Out:
# ImageView object:
#   Display bands       :  [55, 41, 12]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [651.0, 14829.0]
#     G: [553.0, 12103.0]
#     B: [46.0, 2632.0]

# %%
view_cube(img, bands=[29, 19, 9])
# Out:
# /home/juand/anaconda3/envs/R_Studio_Python/lib/python3.7/site-packages/spectral/graphics/graphics.py:800: UserWarning:
# There is no current wx.App object - creating one now.
#   UserWarning)
# ---------------------------------------------------------------------
# wxAssertionError                    Traceback (most recent call last)
# ~/anaconda3/envs/R_Studio_Python/lib/python3.7/site-packages/spectral/graphics/hypercube.py in on_resize(self, event)
#     479
#     480         if wx.VERSION >= (2, 9) or self.canvas.GetContext():
# --> 481             self.canvas.SetCurrent(self.canvas.context)
#     482             self.Show()
#     483             size = self.canvas.GetClientSize()
#
# wxAssertionError: C++ assertion "xid" failed at /tmp/build/80754af9/wxpython_1547931003892/work/ext/wxWidgets/src/unix/glx11.cpp(194) in SetCurrent(): window must be shown
# Mouse Functions:
# ----------------
# left-click & drag        ->   Rotate cube
# CTRL+left-click & drag   ->   Zoom in/out
# ...

# %%
band = img[:, :, 9]
print(band)
# Out:
# [[[1490]
#   [1428]
#   [1544]
#   ...
#   [1291]
#   [1337]
#   [1358]]
#
#  [[1502]
#   [1515]
#   [1519]
#   ...
#   [1398]
#   [1373]
#   [1367]]
#
#  [[1546]
#   [1471]
#   [1501]
#   ...
#   [1336]
#   [1506]
#   [1278]]
#
#  ...
#
#  [[ 166]
#   [ 156]
#   [ 160]
#   ...
#   [  88]
#   [ 140]
#   [ 122]]
#
#  [[ 166]
#   [ 187]
#   [ 166]
#   ...
#   [ 159]
#   [  87]
#   [  87]]
#
#  [[ 160]
#   [ 150]
#   [ 154]
#   ...
#   [ 168]
#   [ 140]
#   [  60]]]
